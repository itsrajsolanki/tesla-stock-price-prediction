# %%
import numpy as np 
import pandas as pd
df=pd.read_csv("Tesla_stock_data.csv")
print(df)
# Out:
#             Date       Close        High         Low        Open     Volume
# 0     2010-06-29    1.592667    1.666667    1.169333    1.266667  281494500
# 1     2010-06-30    1.588667    2.028000    1.553333    1.719333  257806500
# 2     2010-07-01    1.464000    1.728000    1.351333    1.666667  123282000
# 3     2010-07-02    1.280000    1.540000    1.247333    1.533333   77097000
# 4     2010-07-06    1.074000    1.333333    1.055333    1.333333  103003500
# ...          ...         ...         ...         ...         ...        ...
# 3915  2026-01-22  449.359985  449.500000  432.630005  435.160004   71546700
# 3916  2026-01-23  449.059998  452.429993  444.040009  447.429993   56771400
# 3917  2026-01-26  435.200012  445.040009  434.279999  445.000000   49397400
# 3918  2026-01-27  430.899994  437.519989  430.690002  437.410004   37733100
# 3919  2026-01-28  431.459991  438.260010  430.100006  431.910004   53657900
#
# [3920 rows x 6 columns]

# %%
df.isnull()
# Out:
#        Date  Close   High    Low   Open  Volume
# 0     False  False  False  False  False   False
# 1     False  False  False  False  False   False
# 2     False  False  False  False  False   False
# 3     False  False  False  False  False   False
# 4     False  False  False  False  False   False
# ...     ...    ...    ...    ...    ...     ...
# 3915  False  False  False  False  False   False
# 3916  False  False  False  False  False   False
# 3917  False  False  False  False  False   False
# 3918  False  False  False  False  False   False
# 3919  False  False  False  False  False   False
#
# [3920 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Date      0
# Close     0
# High      0
# Low       0
# Open      0
# Volume    0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 3915    False
# 3916    False
# 3917    False
# 3918    False
# 3919    False
# Length: 3920, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head()
# Out:
#          Date     Close      High       Low      Open     Volume
# 0  2010-06-29  1.592667  1.666667  1.169333  1.266667  281494500
# 1  2010-06-30  1.588667  2.028000  1.553333  1.719333  257806500
# 2  2010-07-01  1.464000  1.728000  1.351333  1.666667  123282000
# 3  2010-07-02  1.280000  1.540000  1.247333  1.533333   77097000
# 4  2010-07-06  1.074000  1.333333  1.055333  1.333333  103003500

# %%
df.tail()
# Out:
#             Date       Close        High         Low        Open    Volume
# 3915  2026-01-22  449.359985  449.500000  432.630005  435.160004  71546700
# 3916  2026-01-23  449.059998  452.429993  444.040009  447.429993  56771400
# 3917  2026-01-26  435.200012  445.040009  434.279999  445.000000  49397400
# 3918  2026-01-27  430.899994  437.519989  430.690002  437.410004  37733100
# 3919  2026-01-28  431.459991  438.260010  430.100006  431.910004  53657900

# %%
df.shape
# Out:
# (3920, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3920 entries, 0 to 3919
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3920 non-null   object
#  1   Close   3920 non-null   float64
#  2   High    3920 non-null   float64
#  3   Low     3920 non-null   float64
#  4   Open    3920 non-null   float64
#  5   Volume  3920 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 183.9+ KB

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df.sort_values("Date")
df["Year"]=df["Date"].dt.year
df["Month"]=df["Date"].dt.month
df["Day"]=df["Date"].dt.day
df.drop(["Date"],axis=1)
# Out:
#            Close        High         Low        Open     Volume  Year  Month  \
# 0       1.592667    1.666667    1.169333    1.266667  281494500  2010      6
# 1       1.588667    2.028000    1.553333    1.719333  257806500  2010      6
# 2       1.464000    1.728000    1.351333    1.666667  123282000  2010      7
# 3       1.280000    1.540000    1.247333    1.533333   77097000  2010      7
# 4       1.074000    1.333333    1.055333    1.333333  103003500  2010      7
# ...          ...         ...         ...         ...        ...   ...    ...
# 3915  449.359985  449.500000  432.630005  435.160004   71546700  2026      1
# 3916  449.059998  452.429993  444.040009  447.429993   56771400  2026      1
# 3917  435.200012  445.040009  434.279999  445.000000   49397400  2026      1
# 3918  430.899994  437.519989  430.690002  437.410004   37733100  2026      1
# 3919  431.459991  438.260010  430.100006  431.910004   53657900  2026      1
#
#       Day
# 0      29
# 1      30
# ...

# %%
df.head
# Out:
# <bound method NDFrame.head of            Date       Close        High         Low        Open     Volume  \
# 0    2010-06-29    1.592667    1.666667    1.169333    1.266667  281494500
# 1    2010-06-30    1.588667    2.028000    1.553333    1.719333  257806500
# 2    2010-07-01    1.464000    1.728000    1.351333    1.666667  123282000
# 3    2010-07-02    1.280000    1.540000    1.247333    1.533333   77097000
# 4    2010-07-06    1.074000    1.333333    1.055333    1.333333  103003500
# ...         ...         ...         ...         ...         ...        ...
# 3915 2026-01-22  449.359985  449.500000  432.630005  435.160004   71546700
# 3916 2026-01-23  449.059998  452.429993  444.040009  447.429993   56771400
# 3917 2026-01-26  435.200012  445.040009  434.279999  445.000000   49397400
# 3918 2026-01-27  430.899994  437.519989  430.690002  437.410004   37733100
# 3919 2026-01-28  431.459991  438.260010  430.100006  431.910004   53657900
#
#       Year  Month  Day
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(df["Close"])
plt.show()

# %%
import seaborn as sns
sns.boxplot(y=df["Close"])
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)
plt.show()

# %%
df["Close_lag1"]=df["Close"].shift(1)
df["Close_lag2"]=df["Close"].shift(2)
df["Close_lag3"]=df["Close"].shift(3)

df["Target"]=df["Close"].shift(-1)

# %%
print(df.isnull().sum())
df=df.dropna().reset_index(drop=True)
# Out:
# Date          0
# Close         0
# High          0
# Low           0
# Open          0
# Volume        0
# Year          0
# Month         0
# Day           0
# Close_lag1    1
# Close_lag2    2
# Close_lag3    3
# Target        1
# dtype: int64

# %%
features=["Open","High","Low","Close","Volume","Close_lag1","Close_lag2","Close_lag3"]

# %%
X=df[features]
Y=df["Target"]

# %%
from sklearn.model_selection import train_test_split
train_size=int(len(df)*0.8)
X_train=X.iloc[:train_size]
X_test=X.iloc[train_size:]
Y_train=Y.iloc[:train_size]
Y_test=Y.iloc[train_size:]

# %%
X_train
# Out:
#             Open        High         Low       Close     Volume  Close_lag1  \
# 0       1.533333    1.540000    1.247333    1.280000   77097000    1.464000
# 1       1.333333    1.333333    1.055333    1.074000  103003500    1.280000
# 2       1.093333    1.108667    0.998667    1.053333  103825500    1.074000
# 3       1.076000    1.168000    1.038000    1.164000  115671000    1.053333
# 4       1.172000    1.193333    1.103333    1.160000   60759000    1.164000
# ...          ...         ...         ...         ...        ...         ...
# 3127  191.779999  196.250000  191.110001  194.860001   73645900  194.699997
# 3128  189.440002  191.270004  180.550003  182.449997   93122700  194.860001
# 3129  181.220001  183.649994  175.330002  179.820007   92150800  182.449997
# 3130  175.029999  179.380005  172.220001  174.039993   84213300  179.820007
# 3131  172.199997  175.199997  169.059998  173.440002   97624500  174.039993
#
#       Close_lag2  Close_lag3
# ...

# %%
X_test
# Out:
#             Open        High         Low       Close     Volume  Close_lag1  \
# 3132  173.839996  182.500000  173.360001  179.050003  104872300  173.440002
# 3133  176.100006  177.369995  167.520004  167.820007  109794500  179.050003
# 3134  174.869995  175.050003  156.910004  160.949997  175862700  167.820007
# 3135  159.250000  161.619995  155.309998  156.800003  140682300  160.949997
# 3136  153.440002  160.929993  153.279999  157.669998  122334500  156.800003
# ...          ...         ...         ...         ...        ...         ...
# 3911  421.660004  438.200012  419.619995  431.440002   68124000  419.250000
# 3912  435.160004  449.500000  432.630005  449.359985   71546700  431.440002
# 3913  447.429993  452.429993  444.040009  449.059998   56771400  449.359985
# 3914  445.000000  445.040009  434.279999  435.200012   49397400  449.059998
# 3915  437.410004  437.519989  430.690002  430.899994   37733100  435.200012
#
#       Close_lag2  Close_lag3
# ...

# %%
Y_test
# Out:
# 3132    167.820007
# 3133    160.949997
# 3134    156.800003
# 3135    157.669998
# 3136    150.229996
#            ...
# 3911    449.359985
# 3912    449.059998
# 3913    435.200012
# 3914    430.899994
# 3915    431.459991
# Name: Target, Length: 784, dtype: float64

# %%
Y_train
# Out:
# 0         1.074000
# 1         1.053333
# 2         1.164000
# 3         1.160000
# 4         1.136667
#            ...
# 3127    182.449997
# 3128    179.820007
# 3129    174.039993
# 3130    173.440002
# 3131    179.050003
# Name: Target, Length: 3132, dtype: float64

# %%
from xgboost import XGBRegressor
from sklearn.metrics import r2_score, mean_squared_error

# %%
model=XGBRegressor(n_estimators=800,
                   learning_rate=0.03,
                   max_depth=6,
                   subsample=0.8,
                   colsample_bytree=0.8,
                  random_state=42)

# %%
model.fit(X_train,Y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              feature_weights=None, gamma=None, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.03, max_bin=None, max_cat_threshold=None,
#              max_cat_to_onehot=None, max_delta_step=None, max_depth=6,
#              max_leaves=None, min_child_weight=None, missing=nan,
#              monotone_constraints=None, multi_strategy=None, n_estimators=800,
#              n_jobs=None, num_parallel_tree=None, ...)

# %%
Y_pred=model.predict(X_test)

# %%
r2=r2_score(Y_test,Y_pred)
rmse=np.sqrt(mean_squared_error(Y_test,Y_pred))
print("R2 Score",r2)
print("MSE", rmse)
# Out:
# R2 Score 0.9203105325735498
# MSE 26.00626021307849

# %%
"""Next_day_input=np.array([[
df["Open"].iloc[-1],
df["High"].iloc[-1],
df["Low"].iloc[-1],
df["Close*"].iloc[-1],
df["Volume"].iloc[-1]
]])"""
# Out:
# 'Next_day_input=np.array([[\ndf["Open"].iloc[-1],\ndf["High"].iloc[-1],\ndf["Low"].iloc[-1],\ndf["Close*"].iloc[-1],\ndf["Volume"].iloc[-1]\n]])'

# %%
Next_day_input=np.array([[
  	421.660004,438.200012,419.619995,431.440002,68124000,419.250000,437.500000,438.570007
    ]])

# %%
Next_day_Close=model.predict(Next_day_input)[0]
print(f" Next Day Close:{Next_day_Close:2f}")
# Out:
#  Next Day Close:390.256378

# %%
X_test
# Out:
#             Open        High         Low       Close     Volume  Close_lag1  \
# 3132  173.839996  182.500000  173.360001  179.050003  104872300  173.440002
# 3133  176.100006  177.369995  167.520004  167.820007  109794500  179.050003
# 3134  174.869995  175.050003  156.910004  160.949997  175862700  167.820007
# 3135  159.250000  161.619995  155.309998  156.800003  140682300  160.949997
# 3136  153.440002  160.929993  153.279999  157.669998  122334500  156.800003
# ...          ...         ...         ...         ...        ...         ...
# 3911  421.660004  438.200012  419.619995  431.440002   68124000  419.250000
# 3912  435.160004  449.500000  432.630005  449.359985   71546700  431.440002
# 3913  447.429993  452.429993  444.040009  449.059998   56771400  449.359985
# 3914  445.000000  445.040009  434.279999  435.200012   49397400  449.059998
# 3915  437.410004  437.519989  430.690002  430.899994   37733100  435.200012
#
#       Close_lag2  Close_lag3
# ...

# %%
import pickle
pickle.dump(model,open("Final_Stock_Tesla_closing_price.pkl","wb"))
